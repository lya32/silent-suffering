# %%
import json
import pandas as pd
from nltk.stem import WordNetLemmatizer
import re, unicodedata
from wordcloud import WordCloud, ImageColorGenerator
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import nltk

pd.set_option('display.max_colwidth', -1)
STOPWORDS = set(stopwords.words('english'))

# %%
# contraction_mapping = {"ive":"i have","ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "havent":"have not","haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }
# def transform(words):
#     word_list = []
#     for word in words.split():
#         new_word = word
#         """Remove punctuation except for "?" and "!" from list of tokenized words"""
#         if contraction_mapping.__contains__(new_word):
#             new_word = contraction_mapping[new_word]
#         word_list.append(new_word)
#     return ' '.join(word_list)

# def normalize(words):
#     word_list = []
#     for word in words:
#         """Remove non-ASCII characters from list of tokenized words"""
#         new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#         """Convert all characters to lowercase from list of tokenized words"""
#         new_word = new_word.lower()
# #         new_word = re.sub(r'[^\w\s]', '', new_word)
#         """Lemmatize verbs in list of tokenized words"""
#         lemmatizer = WordNetLemmatizer()
#         new_word = lemmatizer.lemmatize(new_word, pos='v')
#         """Replace all interger occurrences in list of tokenized words with textual representation"""
# #         if new_word.isdigit():
# #             new_word = 'digit'
#         if new_word != '':
#             word_list.append(new_word)
#     return word_list

def transform(line):
    contraction_mapping = {"ive":"i have","dont":"do not","cant":"can not","ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "havent":"have not","haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }
    word_list = []
    """Convert all characters to lowercase"""
    line = line.lower().replace("."," . ").replace(',',' , ').replace("?"," ? ").replace("!"," ! ").replace('"',' " ').replace(':',' : ').replace('\n', ' ').replace('/', ' / ').replace('_', ' ')
    for word in line.split():
        new_word = word
        """Remove punctuation except for "?" and "!" from list of tokenized words"""
        if contraction_mapping.__contains__(new_word):
            new_word = contraction_mapping[new_word]
        word_list.append(new_word)
    return ' '.join(word_list)

def normalize(word):
    """Remove non-ASCII characters from list of tokenized words"""
    new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    new_word = re.sub(r'[^\w\s.!?:,-]', '', new_word)
    lemmatizer = WordNetLemmatizer()
    new_word = lemmatizer.lemmatize(new_word, pos='v')
    return new_word

# %%
def sent_preprocessing(sent):
    return " ".join([normalize(word) for word in word_tokenize(transform(sent)) if normalize(word) != ""]).strip()

# %%
data = []
with open("../Crawling/PostProcessing/Abdominal_Disorders_Merged_Discussion.jl") as f:
#     for line in f.readlines():
       df = pd.DataFrame(json.loads(line) for line in f)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143961 entries, 0 to 143960
# Data columns (total 5 columns):
# content_id    143961 non-null object
# post_type     143961 non-null object
# poster        143961 non-null object
# text          143961 non-null object
# timestamp     143961 non-null object
# dtypes: object(5)
# memory usage: 5.5+ MB
#   content_id   post_type        poster  \
# 0  702603     discussion  chrissey
# 1  702603     reply       suzanne54870
# 2  702603     reply       edna29227
# 3  702603     reply       suzanne54870
# 4  702603     reply       edna29227
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text  \
# 0  I've just been diagnosed at 47 and feel like s--t so angry feel like the world hates me, I'm thinking about hrt  but mg mum hadbreast cancer17 years ago any advice gratefully received
# 1  Hi Chrissey, given your history please weigh your choices carefully. If you do choose to go HRT route, please consider doing creams (bioidenticals) as there might not be as many side effects.
# 2  Hi Chrissey, pls try other options you can find.  Better avoid HRT.  I was also told to avoid soy in excess.I am post menopause and I find it disrupting my daily activities.  Coping is sometimes very hard but we have to move forward.  I keep telling myself it's not the end of the world and it is a natural process.  Tough for us who are getting the worst of it.  I thank God this forum makes me sane.  Knowing that you are not alone helps a lot.  And there is God who gives me strength through all this.  God bless you.\n                                                                                                                                                            Report
# 3  Hi Chrissey, given your history please weigh your choices carefully. If you do choose to go HRT route, please consider doing creams (bioidenticals) as there might not be as many side effects.
# 4  Hi Chrissey, pls try other options you can find.  Better avoid HRT.  I was also told to avoid soy in excess.I am post menopause and I find it disrupting my daily activities.  Coping is sometimes very hard but we have to move forward.  I keep telling myself it's not the end of the world and it is a natural process.  Tough for us who are getting the worst of it.  I thank God this forum makes me sane.  Knowing that you are not alone helps a lot.  And there is God who gives me strength through all this.  God bless you.\n                                                                                                                                                            Report
#
#                 timestamp
# 0  2019-05-23T11:33+00:00
# 1  2019-05-23T12:13+00:00
# 2  2019-05-24T00:36+00:00
# 3  2019-05-23T12:13+00:00
# 4  2019-05-24T00:36+00:00

# %%
df["text"] = df.text.apply(lambda x: sent_preprocessing(x))
df.head()
# Out:
#   content_id   post_type        poster  \
# 0  702603     discussion  chrissey
# 1  702603     reply       suzanne54870
# 2  702603     reply       edna29227
# 3  702603     reply       suzanne54870
# 4  702603     reply       edna29227
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text  \
# 0  i have just be diagnose at 47 and feel like s -- t so angry feel like the world hat me , i be think about hrt but mg mum hadbreast cancer17 years ago any advice gratefully receive
# 1  hi chrissey , give your history please weigh your choices carefully . if you do choose to go hrt route , please consider do cream bioidenticals as there might not be as many side effect .
# 2  hi chrissey , pls try other options you can find . better avoid hrt . i be also tell to avoid soy in excess . i be post menopause and i find it disrupt my daily activities . cop be sometimes very hard but we have to move forward . i keep tell myself it be not the end of the world and it be a natural process . tough for us who be get the worst of it . i thank god this forum make me sane . know that you be not alone help a lot . and there be god who give me strength through all this . god bless you . report
# 3  hi chrissey , give your history please weigh your choices carefully . if you do choose to go hrt route , please consider do cream bioidenticals as there might not be as many side effect .
# 4  hi chrissey , pls try other options you can find . better avoid hrt . i be also tell to avoid soy in excess . i be post menopause and i find it disrupt my daily activities . cop be sometimes very hard but we have to move forward . i keep tell myself it be not the end of the world and it be a natural process . tough for us who be get the worst of it . i thank god this forum make me sane . know that you be not alone help a lot . and there be god who give me strength through all this . god bless you . report
#
#                 timestamp
# 0  2019-05-23T11:33+00:00
# 1  2019-05-23T12:13+00:00
# 2  2019-05-24T00:36+00:00
# 3  2019-05-23T12:13+00:00
# 4  2019-05-24T00:36+00:00

# %%
from nltk import ngrams
from collections import Counter

# ## Helper Functions (Original)
# def get_ngrams(text, n):
#     n_grams = ngrams((text), n)
#     return [ ' '.join(grams) for grams in n_grams]

# def gramfreq(text,n,num):
#     # Extracting bigrams
#     result = get_ngrams(text,n)
#     # Counting bigrams
#     result_count = Counter(result)
#     # Converting to the result to a data frame
#     df = pd.DataFrame.from_dict(result_count, orient='index')
#     df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
#     return df.sort_values(["frequency"],ascending=[0])[:num]

# def gram_table(x, gram, length):
#     out = pd.DataFrame(index=None)
#     for i in gram:
#         table = pd.DataFrame(gramfreq(preprocessing(df[df.author == x]['text']),i,length).reset_index())
#         table.columns = ["{}-Gram".format(i),"Occurence"]
#         out = pd.concat([out, table], axis=1)
#     return out


## Helper Functions
def get_ngrams(text, n):
    result = []
    for line in text:
        token_sent = word_tokenize(line)
        tag_dic = {each[0]:each[1] for each in nltk.pos_tag(token_sent)}
        n_grams = ngrams(token_sent, n)
        filtered = []
        
        for grams in n_grams:
#             if set(' '.join(grams).split()).intersection(set(STOPWORDS)) == set():
            condition = False
            if tag_dic[grams[-1]] == "NN":
                    condition = True
            if set(grams).intersection(STOPWORDS) != set() or set(grams).intersection([',','.','?', '!', ':', '/', '_', '(', ')','...','}', '{']) != set():
                condition = False
            if condition == True:
                filtered.append(' '.join(grams))
        if len(filtered) != 0:
            result.extend(filtered)
    return result

def gramfreq(text,n,num):
    # Extracting bigrams
    result = get_ngrams(text,n)
    # Counting bigrams
    result_count = Counter(result)
    # Converting to the result to a data frame
    df = pd.DataFrame.from_dict(result_count, orient='index')
    df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
    return df.sort_values(["frequency"],ascending=[0])[:num]

def gram_table(textList, gram, length):
    out = pd.DataFrame(index=None)
    for i in gram:
        table = pd.DataFrame(gramfreq(textList,i,length).reset_index())
        table.columns = ["{}-Gram".format(i),"Occurence"]
        out = pd.concat([out, table], axis=1)
    return out

# %%
# gram_table(group="Citalopram", gram=[1,2,3,4], length=20)  One can indicate the classification to be count
gram_df = gram_table(df["text"], gram=[1,2,3,4], length=100)
gram_df.head(50)
# Out:
#           1-Gram  Occurence              2-Gram  Occurence  \
# 0   time          31495      hot flash           3946
# 1   hi            29251      last year           2992
# 2   report        27559      blood test          2754
# 3   anxiety       21820      good luck           2521
# 4   pain          19646      hot flush           2515
# 5   day           18743      side effect         2507
# 6   menopause     16859      take care           2293
# 7   doctor        15189      night sweat         2186
# 8   period        13983      panic attack        2108
# 9   feel          11994      every day           1936
# 10  year          11607      joint pain          1741
# 11  help          11267      one day             1656
# 12  lot           10839      health anxiety      1607
# 13  peri          10806      blood pressure      1569
# 14  hrt           10798      peri menopause      1395
# 15  body          10509      last week           1292
# 16  life          10477      x report            1268
# 17  test          10140      xx report           1228
# 18  work          9944       blood work          1159
# 19  something     9814       last night          1037
# 20  night         9631       take hrt            1023
# 21  thing         9475       progesterone cream  1013
# 22  blood         8855       mood swing          959
# 23  week          8499       back pain           921
# 24  issue         8189       last period         895
# 25  way           8012       brain fog           871
# 26  thank         7719       long time           862
# 27  post          7445       low dose            835
# 28  anything      7403       first time          825
# 29  heart         7396       thank god           820
# 30  anyone        6903       weight gain         814
# 31  everything    6857       heart attack        809
# 32  month         6690       birth control       793
# 33  nothing       6168       acid reflux         774
# 34  head          5967       post menopause      773
# 35  today         5807       next week           772
# 36  age           5751       leave side          763
# 37  change        5637       hormone level       759
# 38  experience    5579       breast cancer       718
# 39  side          5447       one thing           695
# 40  progesterone  5358       lose weight         672
# 41  start         5185       big hug             647
# 42  level         5168       last month          623
# 43  health        5146       every time          613
# 44  estrogen      5041       post meno           603
# 45  morning       4876       make sense          579
# 46  try           4736       many time           578
# 47  dr            4676       every month         577
# 48  ache          4670       take anything       564
# 49  depression    4623       next day            552
#
#                          3-Gram  Occurence  \
# 0   high blood pressure          321
# 1   anyone else experience       270
# 2   lower back pain              263
# 3   even primrose oil            197
# 4   natural progesterone cream   186
# 5   feel like crap               179
# 6   take good care               164
# 7   apple cider vinegar          161
# 8   birth control pill           156
# 9   health food store            152
# 10  feel like something          149
# 11  hormone replacement therapy  148
# 12  feel like im                 143
# 13  get hot flush                139
# 14  every single day             131
# 15  work full time               129
# 16  get hot flash                127
# 17  feel like cry                124
# 18  cod liver oil                121
# 19  low blood sugar              117
# 20  low blood pressure           112
# 21  use progesterone cream       100
# 22  take one day                 99
# 23  anxiety panic attack         98
# 24  happy new year               97
# 25  full blow menopause          89
# 26  blood test show              88
# 27  good luck report             88
# 28  year old daughter            84
# 29  roller coaster ride          82
# 30  fsh blood test               82
# 31  feel like someone            81
# 32  low dose birth               81
# 33  dose birth control           81
# 34  sound like peri              81
# 35  get night sweat              78
# 36  almost every day             78
# 37  low back pain                77
# 38  keep us post                 75
# 39  bad side effect              73
# 40  bio identical hormone        68
# 41  low dose hrt                 68
# 42  anyone else suffer           67
# 43  every little thing           66
# 44  time last year               66
# 45  blood test result            66
# 46  epsom salt bath              66
# 47  mirena coil fit              65
# 48  take care report             62
# 49  vit b complex                61
#
#                                       4-Gram  Occurence
# 0   low dose birth control                    79
# 1   feel better soon report                   44
# 2   still get hot flush                       42
# 3   key brain chemical need                   39
# 4   support healthy adrenal function          39
# 5   take even primrose oil                    38
# 6   bio identical hormone replacement         37
# 7   dose birth control pill                   37
# 8   good luck xx report                       36
# 9   hot flash night sweat                     33
# 10  full blow panic attack                    33
# 11  hug -- sarah report                       32
# 12  experience thoughts around self-harm      30
# 13  bio identical progesterone cream          28
# 14  big hug -- sarah                          26
# 15  take care x report                        24
# 16  alleviate menopausal mood swing           24
# 17  may alleviate menopausal mood             24
# 18  b6 may alleviate menopausal               24
# 19  better soon x report                      22
# 20  good luck x report                        20
# 21  better soon xx report                     20
# 22  comfort hug x report                      20
# 23  big hug xx report                         20
# 24  swing vitamin b6vitamin b6                19
# 25  night sweat every night                   19
# 26  feel like im die                          18
# 27  take good care report                     18
# 28  woman may become alarm                    18
# 29  take vit b complex                        17
# 30  hot flush night sweat                     17
# 31  use natural progesterone cream            16
# 32  10 year peri hell                         16
# 33  take cod liver oil                        16
# 34  im ten yrs post                           16
# 35  really bad health anxiety                 15
# 36  bioidentical hormone replacement therapy  15
# 37  get better one day                        15
# 38  ten year natural peri                     14
# 39  take apple cider vinegar                  14
# 40  always feel like something                14
# 41  take vitamin b complex                    14
# 42  stop long term bcp                        14
# 43  long term bcp use                         14
# 44  exchange contact detail please            14
# 45  back within normal range                  13
# 46  14 days per month                         13
# 47  white blood cell count                    13
# 48  pretty much every symptom                 13
# 49  ovestin estriol vaginal cream             13

# %%
out_path = 'Abdominal_Disorders_Frequent_Ngram.csv'
gram_df.to_csv(out_path, index=False)

# %%
# wordcloud = WordCloud(max_font_size=30, max_words=200, background_color="black", stopwords=STOPWORDS).generate(wholestr)
# plt.figure(figsize=(50,50))
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()
