# %%
import json
import pandas as pd
from nltk.stem import WordNetLemmatizer
import re, unicodedata
from wordcloud import WordCloud, ImageColorGenerator
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import nltk

pd.set_option('display.max_colwidth', -1)
STOPWORDS = set(stopwords.words('english'))

# %%
# contraction_mapping = {"ive":"i have","ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "havent":"have not","haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }
# def transform(words):
#     word_list = []
#     for word in words.split():
#         new_word = word
#         """Remove punctuation except for "?" and "!" from list of tokenized words"""
#         if contraction_mapping.__contains__(new_word):
#             new_word = contraction_mapping[new_word]
#         word_list.append(new_word)
#     return ' '.join(word_list)

# def normalize(words):
#     word_list = []
#     for word in words:
#         """Remove non-ASCII characters from list of tokenized words"""
#         new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#         """Convert all characters to lowercase from list of tokenized words"""
#         new_word = new_word.lower()
# #         new_word = re.sub(r'[^\w\s]', '', new_word)
#         """Lemmatize verbs in list of tokenized words"""
#         lemmatizer = WordNetLemmatizer()
#         new_word = lemmatizer.lemmatize(new_word, pos='v')
#         """Replace all interger occurrences in list of tokenized words with textual representation"""
# #         if new_word.isdigit():
# #             new_word = 'digit'
#         if new_word != '':
#             word_list.append(new_word)
#     return word_list

def transform(line):
    contraction_mapping = {"ive":"i have","dont":"do not","cant":"can not","ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "havent":"have not","haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }
    word_list = []
    """Convert all characters to lowercase"""
    line = line.lower().replace("."," . ").replace(',',' , ').replace("?"," ? ").replace("!"," ! ").replace('"',' " ').replace(':',' : ').replace('\n', ' ').replace('/', ' / ').replace('_', ' ')
    for word in line.split():
        new_word = word
        """Remove punctuation except for "?" and "!" from list of tokenized words"""
        if contraction_mapping.__contains__(new_word):
            new_word = contraction_mapping[new_word]
        word_list.append(new_word)
    return ' '.join(word_list)

def normalize(word):
    """Remove non-ASCII characters from list of tokenized words"""
    new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    new_word = re.sub(r'[^\w\s.!?:,-]', '', new_word)
    lemmatizer = WordNetLemmatizer()
    new_word = lemmatizer.lemmatize(new_word, pos='v')
    return new_word

# %%
def sent_preprocessing(sent):
    return " ".join([normalize(word) for word in word_tokenize(transform(sent)) if normalize(word) != ""]).strip()

# %%
data = []
with open("../Crawling/PostProcessing/Citalopram_Merged_Discussion.jl") as f:
#     for line in f.readlines():
       df = pd.DataFrame(json.loads(line) for line in f)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4792 entries, 0 to 4791
# Data columns (total 5 columns):
# content_id    4792 non-null object
# post_type     4792 non-null object
# poster        4792 non-null object
# text          4792 non-null object
# timestamp     4792 non-null object
# dtypes: object(5)
# memory usage: 187.3+ KB
#   content_id               post_type         poster  \
# 0  702262     discussion and replies  Sally_66
# 1  581829     discussion and replies  gillian176
# 2  702444     discussion and replies  racheld1975
# 3  700076     discussion and replies  marketta48368
# 4  702426     discussion and replies  Potatoghost
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0
you think they would know something . other than oh yoh will be find in two weeks . i guess they do not want to verbally scare their patients . with med drama . take me eight months . i know everyones chemistry be different . and iam still improve after be on them for roughly 3years . most definitely . both . oh my goodness it be and be the best feel ever . yes for 8full months . completely go . that be why i would never come off . can not risk that ant feel terrorize me again . i have be on citalopram a total of 7 months now , i be initially on 10mg , they increase me to 20mg and i stay on that for 5 . 5 months . i find that the 20mg seem much to high for me , it make me numb emotionally , and just felt weird so i reduce to 15mg , and so far and the past week i feel much more like my old self . so it be really a guess game as to the right dose , and how long it take to feel much better . you will have periods of feel better , and then a dip , then feel better , to where the dip happen rarely and the majority of time you feel good . do not get discourage if you have a dip just bare through it and tell yourself its temp and you be still on the path to feel better ! my doctor also tell me 6-8 weeks for full effect , that be so far from true for most people , most of the time . i would say you should start have some good days by then , and they will continue to increase for months , some people have say up to 7-8 months . so just give it time , stick with it . best wish ! i totally understand the adrenaline drama . i have that for 8months . it would start in my stomach and it would end on top of my head the most bizzare feel in the world . yes despair be definitely the correct definition . like omg what be happen why do i feel like this . etc . ah , the good old doctor advice again ...... . it may be that the meds reach their peak by 4-6 weeks i m not a medic so have no idea but that doesn t mean you wil ...
#
#                 timestamp
# 0  2019-05-19T12:42+00:00
# 1  2017-03-20T09:14+00:00
# 2  2019-05-21T13:30+00:00
# 3  2019-04-23T15:12+00:00
# 4  2019-05-21T09:31+00:00

# %%
from nltk import ngrams
from collections import Counter

# ## Helper Functions (Original)
# def get_ngrams(text, n):
#     n_grams = ngrams((text), n)
#     return [ ' '.join(grams) for grams in n_grams]

# def gramfreq(text,n,num):
#     # Extracting bigrams
#     result = get_ngrams(text,n)
#     # Counting bigrams
#     result_count = Counter(result)
#     # Converting to the result to a data frame
#     df = pd.DataFrame.from_dict(result_count, orient='index')
#     df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
#     return df.sort_values(["frequency"],ascending=[0])[:num]

# def gram_table(x, gram, length):
#     out = pd.DataFrame(index=None)
#     for i in gram:
#         table = pd.DataFrame(gramfreq(preprocessing(df[df.author == x]['text']),i,length).reset_index())
#         table.columns = ["{}-Gram".format(i),"Occurence"]
#         out = pd.concat([out, table], axis=1)
#     return out


## Helper Functions
def get_ngrams(text, n):
    result = []
    for line in text:
        token_sent = word_tokenize(line)
        tag_dic = {each[0]:each[1] for each in nltk.pos_tag(token_sent)}
        n_grams = ngrams(token_sent, n)
        filtered = []
        
        for grams in n_grams:
#             if set(' '.join(grams).split()).intersection(set(STOPWORDS)) == set():
            condition = False
            if tag_dic[grams[-1]] == "NN":
                    condition = True
            if set(grams).intersection(STOPWORDS) != set() or set(grams).intersection([',','.','?', '!', ':', '/', '_', '(', ')','...','}', '{']) != set():
                condition = False
            if condition == True:
                filtered.append(' '.join(grams))
        if len(filtered) != 0:
            result.extend(filtered)
    return result

def gramfreq(text,n,num):
    # Extracting bigrams
    result = get_ngrams(text,n)
    # Counting bigrams
    result_count = Counter(result)
    # Converting to the result to a data frame
    df = pd.DataFrame.from_dict(result_count, orient='index')
    df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
    return df.sort_values(["frequency"],ascending=[0])[:num]

def gram_table(textList, gram, length):
    out = pd.DataFrame(index=None)
    for i in gram:
        table = pd.DataFrame(gramfreq(textList,i,length).reset_index())
        table.columns = ["{}-Gram".format(i),"Occurence"]
        out = pd.concat([out, table], axis=1)
    return out

# %%
# gram_table(group="Citalopram", gram=[1,2,3,4], length=20)  One can indicate the classification to be count
gram_df = gram_table(df["text"], gram=[1,2,3,4], length=100)
gram_df.head(50)
# Out:
#         1-Gram  Occurence              2-Gram  Occurence  \
# 0   time        13262      side effect         8095
# 1   anxiety     10898      take care           1283
# 2   effect      9685       panic attack        1235
# 3   day         8017       good luck           1161
# 4   side        6932       take citalopram     721
# 5   citalopram  6509       20 mg               674
# 6   work        5642       long time           642
# 7   week        5344       first time          611
# 8   doctor      4677       last night          597
# 9   dose        4526       take time           577
# 10  feel        4023       10 mg               575
# 11  hi          3735       last week           554
# 12  depression  3423       every day           512
# 13  cit         3413       last year           487
# 14  life        3304       one day             476
# 15  lot         3285       cold turkey         384
# 16  way         3014       second time         327
# 17  night       2978       good day            319
# 18  anyone      2963       take cit            296
# 19  morning     2801       next week           289
# 20  everyone    2777       hi everyone         276
# 21  help        2755       first week          272
# 22  today       2752       dry mouth           258
# 23  think       2533       5 mg                252
# 24  medication  2508       one thing           249
# 25  something   2474       next day            235
# 26  thing       2465       keep post           231
# 27  body        2433       morning anxiety     230
# 28  bite        2384       mental health       229
# 29  increase    2369       best regard         220
# 30  year        2328       increase anxiety    217
# 31  drug        2257       brain zap           216
# 32  mg          2117       last time           212
# 33  gp          1955       old self            211
# 34  post        1908       low dose            207
# 35  try         1863       long term           206
# 36  anything    1835       every time          198
# 37  thank       1778       higher dose         192
# 38  experience  1738       make sense          191
# 39  advice      1717       take mine           183
# 40  brain       1678       blood pressure      177
# 41  month       1662       start citalopram    176
# 42  start       1658       weight gain         172
# 43  care        1636       hope everyone       171
# 44  attack      1583       good idea           169
# 45  head        1569       stick plaster       168
# 46  mind        1493       withdrawal effect   167
# 47  need        1455       40 mg               166
# 48  recovery    1360       anxiety depression  163
# 49  everything  1351       bad day             158
#
#                          3-Gram  Occurence  \
# 0   get side effect              180
# 1   go cold turkey               173
# 2   bad side effect              143
# 3   anyone else experience       113
# 4   start take citalopram        111
# 5   horrible side effect         83
# 6   work relate stress           81
# 7   initial side effect          77
# 8   common side effect           74
# 9   many side effect             66
# 10  awful side effect            62
# 11  take care everyone           62
# 12  terrible side effect         55
# 13  different side effect        55
# 14  experience side effect       55
# 15  nasty side effect            50
# 16  high blood pressure          48
# 17  every side effect            47
# 18  keep us post                 45
# 19  start take cit               44
# 20  original patient experience  44
# 21  work full time               43
# 22  less side effect             42
# 23  natural ssri call            39
# 24  cause side effect            38
# 25  take one day                 38
# 26  sleep last night             36
# 27  citalopram 20 mg             36
# 28  early morning anxiety        35
# 29  post natal depression        34
# 30  stop take citalopram         34
# 31  possible side effect         33
# 32  anxiety panic attack         32
# 33  normal side effect           32
# 34  year old son                 32
# 35  horrendous side effect       32
# 36  good day today               32
# 37  20 mg citalopram             31
# 38  feel like crap               30
# 39  year old daughter            30
# 40  sexual side effect           29
# 41  cita cause anxiety           29
# 42  roller coaster ride          28
# 43  feel better today            28
# 44  take 10 mg                   28
# 45  take different time          27
# 46  stop cold turkey             26
# 47  really interest read         26
# 48  bad panic attack             26
# 49  good luck everyone           26
#
#                                   4-Gram  Occurence
# 0   add extras side effect                17
# 1   long term side effect                 14
# 2   still get side effect                 14
# 3   really bad side effect                12
# 4   10 year old daughter                  12
# 5   20 year old son                       11
# 6   full blow panic attack                11
# 7   really bad panic attack               10
# 8   everyone take different time          10
# 9   first start take citalopram           9
# 10  probably get side effect              9
# 11  first start take cit                  9
# 12  everyone suit different dose          8
# 13  experience thoughts around self-harm  8
# 14  take care regard marcel               8
# 15  get bad side effect                   8
# 16  break leg take time                   8
# 17  still get panic attack                8
# 18  take omega 3 capsule                  8
# 19  take longer second time               7
# 20  sleep well last night                 7
# 21  please keep us post                   7
# 22  sound like side effect                7
# 23  people get better quicker             7
# 24  start get panic attack                7
# 25  twice - first time                    6
# 26  real bad side effect                  6
# 27  anxiety fear anxiety cycle            6
# 28  may get side effect                   6
# 29  post traumatic stress disorder        6
# 30  first dose last night                 6
# 31  still experience side effect          6
# 32  ever go cold turkey                   6
# 33  good week last week                   6
# 34  3-5 every 2-4 week                    5
# 35  vivid dream every night               5
# 36  take 10 mg citalopram                 5
# 37  take st johns wort                    5
# 38  side effect every time                5
# 39  come back full force                  5
# 40  good days last week                   5
# 41  help burn excess adrenaline           5
# 42  take citalopram 20 mg                 5
# 43  stop work become desensitise          5
# 44  feel much better today                5
# 45  get really bad anxiety                5
# 46  x emis moderator comment              5
# 47  side effect like nausea               5
# 48  side effect - nausea                  5
# 49  panic attack last night               5

# %%
out_path = 'Citalopram_Frequent_Ngram.csv'
gram_df.to_csv(out_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-da6cb2345a9c> in <module>
#       1 out_path = '/data/tst.csv'
# ----> 2 gram_df.to_csv(out_path, index=False)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/tst.csv'

# %%
# wordcloud = WordCloud(max_font_size=30, max_words=200, background_color="black", stopwords=STOPWORDS).generate(wholestr)
# plt.figure(figsize=(50,50))
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()
