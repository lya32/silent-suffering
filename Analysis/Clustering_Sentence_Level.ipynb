# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pandas as pd
import json
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re, unicodedata
import nltk
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score, calinski_harabaz_score
from rake_nltk import Metric, Rake
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('whole_sentence_level.csv', index_col=False).drop(['Unnamed: 0', 'trainOrtest'],axis=1)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8389152 entries, 0 to 8389151
# Data columns (total 4 columns):
# aspect    object
# group     object
# id        object
# text      object
# dtypes: object(4)
# memory usage: 256.0+ MB
#   aspect                group                              id  \
# 0     []  Abdominal_Disorders  Abdominal_Disorders--12291-0-1
# 1     []  Abdominal_Disorders  Abdominal_Disorders--12291-0-2
# 2     []  Abdominal_Disorders  Abdominal_Disorders--12291-1-1
# 3     []  Abdominal_Disorders  Abdominal_Disorders--12291-1-2
# 4     []  Abdominal_Disorders  Abdominal_Disorders--12291-2-1
#
#                                                 text
# 0  i be 34 have have a stoma since 28. it have ru...
# 1  there be no help for us we be on our own compl...
# 2  it be the embarrasment or other people embarra...
# 3                                              etc .
# 4                             because of ruby rise .

# %%
stop_words_list = ["he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "a", "an", "the", "and", "of", "at", "by", "for", "with", "about", "into", "through", "during", "to", "from", "then", "once", "here", "there", "both", "each",  "some", "such","own", "than", "don", "now"]
Tfidf_vectorizer = TfidfVectorizer(max_features=5000,
                                   min_df=2, 
#                                    ngram_range=(1, 3),
                                   analyzer='word',
                                   stop_words = stop_words_list)

vectorizer = Tfidf_vectorizer.fit(df["text"])

# %%
text_vectors = vectorizer.transform(df[df.group == 'Abdominal_Disorders']["text"]).toarray()

# %%
silhouette_avg = []
ch_score =[]
range_n_clusters = range(2,21)
for n_clusters in range_n_clusters:
    clusterer  = KMeans(n_clusters=n_clusters, random_state=0, n_jobs=-1)
    cluster_labels = clusterer.fit_predict(text_vectors)
    silhouette_avg.append(silhouette_score(text_vectors, cluster_labels))
    ch_score.append(calinski_harabaz_score(text_vectors, cluster_labels)) 
    print ('k = ', n_clusters)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5310bf76cf47> in <module>
#       4 for n_clusters in range_n_clusters:
#       5     clusterer  = KMeans(n_clusters=n_clusters, random_state=0, n_jobs=-1)
# ----> 6     cluster_labels = clusterer.fit_predict(text_vectors)
#       7     silhouette_avg.append(silhouette_score(text_vectors, cluster_labels))
#       8     ch_score.append(calinski_harabaz_score(text_vectors, cluster_labels))
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit_predict(self, X, y, sample_weight)
#     995             Index of the cluster each sample belongs to.
#     996         """
# --> 997         return self.fit(X, sample_weight=sample_weight).labels_
#     998
#     999     def fit_transform(self, X, y=None, sample_weight=None):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     396                                    # Change seed to ensure variety
#     397                                    random_state=seed)
# --> 398             for seed in seeds)
#     399         # Get results with the lowest inertia
#     400         labels, inertia, centers, n_iters = zip(*results)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda2/envs/py36/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda2/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ####  Calinski-Harabasz scores for clustering

# %%
x = np.arange(2,21,1)
plt.plot(x, ch_score,'ro-')
plt.xlabel('The number of K')
plt.ylabel('CH index')
# Out:
# Text(0, 0.5, 'CH index')

# %% [markdown]
# ####  Silhouette scores for clustering

# %%
# Silhouette scores for clustering
x = np.arange(2,21,1)
plt.plot(x, silhouette_avg,'bo-')
plt.xlabel('The number of K')
plt.ylabel('The average silhouette_score')
# Out:
# Text(0, 0.5, 'The average silhouette_score')

# %%
best_k = 2
best_clusterer  = KMeans(n_clusters=2, random_state=0, n_jobs=-1)
cluster_labels = best_clusterer.fit_predict(text_vectors)

# %%
cluster_text = {}
for index, clsuter_number in enumerate(cluster_labels):
    if cluster_text.__contains__(clsuter_number):
        cluster_text[clsuter_number]["text"] += " " + df["text"].iloc[index]
    else:
        cluster_text[clsuter_number] = {}
        cluster_text[clsuter_number]["text"] = df["text"].iloc[index]

# %%
from nltk.corpus import stopwords
def load_stop_words(stop_word_file):
    """
    Utility function to load stop words from a file and return as a list of words
    @param stop_word_file Path and file name of a file containing stop words.
    @return list A list of stop words.
    """
    stop_words = []
    for line in open(stop_word_file):
        if line.strip()[0:1] != "#":
            for word in line.split():  # in case more than one per line
                stop_words.append(word)
    return stop_words

# %%
def gramfreq(text,n,num):
    # Extracting bigrams
    result = get_ngrams(text,n)
    # Counting bigrams
    result_count = Counter(result)
    # Converting to the result to a data frame
    df = pd.DataFrame.from_dict(result_count, orient='index')
    df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
    return df.sort_values(["frequency"],ascending=[0])[:num]

def gram_table(input_dic, gram, length):
    out = pd.DataFrame(index=None)
    for i in gram:
        for num_cluster in range(len(input_dic)):
            r = Rake(min_length=1, max_length=i, stopwords=stopwords_list)
            r.extract_keywords_from_text(cluster_text[num_cluster]['text'])
            table = pd.DataFrame(r.get_ranked_phrases()[:length])
            table.columns = ["Cluster {0}: {1}-Gram Keywords".format(num_cluster, i)]
            out = pd.concat([out, table], axis=1)
    return out

# %%
stoppath = "SmartStoplist.txt"
stopwords_list = load_stop_words(stoppath)

# %%
gram_df = gram_table(cluster_text, gram=[1,2, 3, 4], length=100)
gram_df.head(50)
# Out:
#    Cluster 0: 1-Gram Keywords Cluster 1: 1-Gram Keywords  \
# 0                      zyrtec                    zyprexa
# 1                       zydol                      zyban
# 2                    zucchini                      zumba
# 3                       zpack                   zucchini
# 4                   zopiclone                      zpack
# 5                        zoom                      zoton
# 6                      zombie                    zophran
# 7                      zoloft                       zoom
# 8                      zofran                  zoolinger
# 9                     zoey112                   zoo12313
# 10                        zoe                        zoo
# 11                    zegerid                       zone
# 12                    zealous                      zolof
# 13                       zate               zolmitriptan
# 14                        zap                    zolfrin
# 15                      zante                    zolfran
# 16                     zantac                       zole
# 17                       zach                     zohrab
# 18                yvonne15233                     zofrin
# 19                        yuo                    zofrani
# 20                  yummmmmmm                     zofran
# 21                     yummmm                     zoflat
# 22                        yuk                        zoe
# 23                       yuck                  zithromax
# 24                        ytd                       zinc
# 25                        yrs                      zetia
# 26                         yr                       zest
# 27                      youve                        zes
# 28                       youu                      zelda
# 29                    youtube                     zegrid
# 30                      youre                      zebra
# 31                   yourarts                  zealander
# 32                 youngsters                    zealand
# 33                    younger                        zap
# 34                      young                     zantex
# 35                   youbhave                    zantacs
# 36                    yogurts                     zantac
# 37                     yogurt                     z13479
# 38                     yogort                  yvonne470
# 39                   yoghurts                     yvonne
# 40                    yoghurt                        yur
# 41                       yoga                        yup
# 42                         yo                      yummy
# 43                        ylu                     yummmm
# 44                        yiu                      yummm
# 45                       yiou                        yuk
# 46                  yesterday                       yuck
# 47                        yep                        yrs
# 48                    yellowy                         yr
# 49                  yellowish                    ypylori
#
#           Cluster 0: 2-Gram Keywords   Cluster 1: 2-Gram Keywords  \
# 0                     zinc carnosine                 zin carosine
# 1                        yummy peach                      yum yum
# 2                           yin yang                    wne tback
# 3                            yelp ow        wireless transmission
# 4                            yah bso             wheened themself
# 5                         wrist band           werthers originals
# 6                          wive tale               waterery stall
# 7                        witch hazel                    wasp buzz
# 8                 wholly unadvisable            vommiting forcely
# 9                       wheel barrow            vogel boldocynara
# 10                 wessex newsletter                  visual arts
# 11                     wellbutrun sr                vist histolic
# 12                  wellbutrin 300mg                vest intreast
# 13                            wan na      vericocele embolization
# 14                        vocal fold                ver conjested
# 15         visceral hypersensitivity       varicella immunisation
# 16                 virtual colonospy           valsalva manoeuvre
# 17                vigourous excerise               vagus manouver
# 18                         vena cava                utterly fedup
# 19                       vacuum pose       unltrasound transducer
# 20                     urban dweller        unleavened knekkebrod
# 21                           ur pooh             umbilical hernai
# 22                     unite kingdom               turner sydrome
# 23              unexplained ganglion                      tsk tsk
# 24               undercooked sausage       transient elastography
# 25                  ultzer cholitius           todays technologly
# 26                  ulcerative colin                   tje diucts
# 27              turner constellation             titanium dioxide
# 28             trulicity dulaglutide                       tid ac
# 29                trishla foundation                  tickety boo
# 30             triage classification             thyroids hormoes
# 31             transversus abdominis           theileria zoonosis
# 32          topographical unevenness            temporal ateritis
# 33                           tic tac                    tak ecare
# 34            thyroiditis antibodies            synthetic vitamic
# 35                      thomas wolfe           swollon intesrines
# 36               tetosterone therepy               sultana muffin
# 37                        tanaya das  sulforaphane isothiocyanate
# 38              takin dihydrocodeine         subsequent exposures
# 39                        suspet wht         streptococcus aureus
# 40                   supply glutafin                 strech myslf
# 41                   superior labrum     sterilization precidures
# 42                   super emptional                 stephie 2394
# 43  streptococcal glomerulonephritis             spinal curvature
# 44                 strawberry flavor                  spinal cord
# 45                  strangest symtom                 spina bifida
# 46                      standby mode             somei nformation
# 47                stall infrequently                 solar plexus
# 48                   splenic flexure            software engineer
# 49                 south oxfordshire                 soccer pitch
#
#            Cluster 0: 3-Gram Keywords  \
# 0   tronolane pramoxine hydrochloride
# 1        sweatiness wetness leakiness
# 2         otilonium bromide spasmomen
# 3                 oat cookies dessert
# 4                       315 thous mcl
# 5           lyloriui kit amoxicilline
# 6                mast cell activation
# 7                dull paine especilly
# 8           national screen programme
# 9                  amino acid taurine
# 10          retroperitoneal lymph nod
# 11            mora therapy practioner
# 12      congnitive behavoural therapy
# 13                  leave iliac fossa
# 14              experience tbes paims
# 15       emontional health definitley
# 16          abdomina pain immediatley
# 17             ehlers danlos syndrome
# 18                    solan de cabras
# 19               secrecy victims bind
# 20             mild chronice gasritis
# 21                 lactic acidosis 2o
# 22          iron deficeincty oranemia
# 23       currentlyon cimetidine 400mg
# 24     british homeopathic assciation
# 25            12th thoracic vertebrae
# 26                    totry mirelax 1
# 27                      cin 1 lastime
# 28                   1 400g ibrofohom
# 29                      weight 185 lb
# 30        similair endocrine disorder
# 31           autism spectrum disorder
# 32      blastocistis hominis bacteria
# 33        bacteria streptococcus equi
# 34              stool wihout strainig
# 35        deadly nightshade sensitive
# 36             mbaddison low cortison
# 37             360 degrees fahrenheit
# 38                 bismuth kill ecoli
# 39             imbalanced gut biodome
# 40                muscel spasms aswel
# 41  experiening constant palpapations
# 42   intestinal hereditary angioedema
# 43                start lithium 900mg
# 44                      hv itchin dwn
# 45                apple cidar vinager
# 46             botch cataract surgery
# 47              food standards agency
# 48        fructan lactose malabsorber
# 49                     afew weeks ago
#
#                  Cluster 1: 3-Gram Keywords  \
# 0                            vhl von hippel
# 1            rectus abdominis succuessfully
# 2                     prague czech republic
# 3             lanperazol emperazol rinidine
# 4                      kapal bhati pranayam
# 5   efprfnswffhsfy2ndi0 posterid163022 rnd0
# 6                               bla bla bla
# 7                     autopsy ensue lawsuit
# 8                 ashkenazi jewish heritage
# 9                               foc yo tedt
# 10                    mast cell stabilizers
# 11        mathematical gaussian calculation
# 12                      blood vials congeal
# 13                              6 167 unfit
# 14                 stomach oddness presists
# 15                             ea ting pain
# 16                 irratable bowel symdrone
# 17                 ganglionic achr antibody
# 18                       pasture raise hens
# 19                 axetine 500mg cefuroxime
# 20                axentine cefuroxime 500mg
# 21                          wan na desapear
# 22           parasympaticus vagus manouvres
# 23                       gov pubmed 3810208
# 24                      gov pubmed 26752337
# 25                      gov pubmed 26466105
# 26                      gov pubmed 26376608
# 27                      gov pubmed 12094008
# 28                      high glycemic index
# 29                     carcionid urine hiaa
# 30              raynauds phonomenom primary
# 31                       bicarb moring test
# 32        antimicrobial susceptibility test
# 33                      h2 blocker niazidin
# 34                  including celaic screen
# 35                          aloe vera jiuce
# 36                       apple granny smith
# 37                     001 low immunoglobin
# 38                   cababge juice andafter
# 39                      vanilla haagen dazs
# 40                      carvedilol 38mg 2xd
# 41          alsobhave eosophagus discomfort
# 42                     norwegian kroners 10
# 43                        eat walkers crips
# 44                   eat drumstick sqashies
# 45                 type natriuertic peptide
# 46                  h2 receptor antagonists
# 47                 h2 receptor anatagonists
# 48                    meseenteric lymph nod
# 49             environmentally pollute food
#
#                         Cluster 0: 4-Gram Keywords  \
# 0         omaperazol lanperazol emperazol rinidine
# 1   keywordsgreenptband qid1552365184 sgateway sr8
# 2                         gca giant cell arteritis
# 3                              jad pain aound wjat
# 4             althaea officinalis marshmallow leaf
# 5                              el pollo loco salad
# 6                equate clearlax osomotic laxative
# 7                           buscas 10 mg medazepam
# 8                    loin pain haematuria syndrome
# 9                     annual ce driver hydrocodone
# 10                       fermentable oligo di mono
# 11           estimate glomerulator filtration rate
# 12                        betaloc 25 mg metaprolol
# 13                                     1k ul rbc 4
# 14         google necrotising enterocolitis forums
# 15                                148 gamma gt 225
# 16           diviculitis divicular disease chrohns
# 17               c1esterase inhibitor blood enzyme
# 18                                  60m mm3 hgb 14
# 19               tabloid newspaper type journalism
# 20                     nexium serc zofran stemital
# 21                median arcuate ligament syndrome
# 22                  unobstructing kidney stone 3mm
# 23                       pylori thnks marissa hang
# 24                     water purifica tion tablets
# 25                         omeorazole 2 months ago
# 26            superior mescenteric artery syndrome
# 27                                 meg 4 years ago
# 28                  medications nexium serc zoflan
# 29                 pqq pyrroloquinoline quinone 10
# 30                  stress couses gastritist ulcer
# 31                               protonix 40 mg x1
# 32                      gov pmc article pmc2059021
# 33                      csnceri requestudo nt ruin
# 34                          68 mill mcl hemoglobin
# 35                           eat pork chasgu ramen
# 36                                diag 2 years ago
# 37                       butter cookie 2months ago
# 38                               20 years ago mits
# 39                               paxil 10 days ago
# 40                gerd barrats osephagus condition
# 41                         optins grid compare lnf
# 42                       dry chemical leaven agent
# 43                   compliant flour cassava flour
# 44               experiensing upper abdominal pain
# 45             technique call component separation
# 46            include alanine aminotransferase alt
# 47                perform schistosoma parasit test
# 48                    linette6464 bright red blood
# 49           squamous oesophageal epithelial cells
#
#                         Cluster 1: 4-Gram Keywords
# 0                  utm sourceforum utm mediumreply
# 1   indigestions nopar spasmolytic anticholinergic
# 2                               natrum phos 6x 12x
# 3               duodendal bulb inflamated bulbitis
# 4              handouts chronic 20abdominal 20pain
# 5               dawnregina dawnregina 4 dawnregina
# 6                     osme anti depressiavant medc
# 7                    touble swalowing difrent type
# 8               john decaestecker janusz jankowski
# 9                        haem arginate aust canada
# 10                              gov gard 6920 loin
# 11       tif transoral incisionless fundoplication
# 12                   2018 acg ajaxcalls posterinfo
# 13                    caking agent silicon dioxide
# 14                      gov pmc article pmc5773269
# 15                      gov pmc article pmc4991651
# 16                      gov pmc article pmc4416293
# 17                      gov pmc article pmc3568682
# 18                      gov pmc article pmc3038319
# 19                      gov pmc article pmc1114430
# 20                           suzy q21 msy posdibly
# 21      crystalise miniscule formations thoughtout
# 22                     tetanus shoot augmentin cal
# 23               carbonic anhydrous antibody issue
# 24                   pesky hiatus hernia meddinces
# 25                   gentic blood test klinefelter
# 26                    worsening lpr airways reflux
# 27                 lpr laryngeal pharyngeal reflux
# 28                         bounty probiotic gx 299
# 29                 famlilal mediterraean fever fmf
# 30                edta intraveinous chelat therapy
# 31                  computerize topography ct scan
# 32                      compute tomography ct scan
# 33               call liver detoxifier regenerator
# 34              esonophilic esophagetis years back
# 35                    irritale bowel snydrome diet
# 36                         avoid ice burg lettuces
# 37              lower espohagus spinchter tighness
# 38                   martin muellers iv foundation
# 39                    martin mueller iv foundation
# 40             curvy bacteria alltogether afterall
# 41                           pigergast 6 weeks ago
# 42                           eat flamin hot ruffle
# 43                        1 gaubladder ulter sound
# 44                esr erythrocite sedimention rate
# 45                    fma fecal microbial analysis
# 46                    fecal microbial analysis fma
# 47            induced enterocolitis syndrome fpies
# 48                                divi 2 years ago
# 49                                py 18 months ago

# %%
out_path = 'Abdominal_Disorders_Clustering_Keywords.csv'
gram_df.to_csv(out_path, index=False)
